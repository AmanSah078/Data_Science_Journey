# %%
import pandas as pd

# %%
#how i can import the file in to the jupyter
movies = pd.read_csv(r"C:\Data_Science\movie.csv\movie.csv")
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
movies.head(20)
# Out:
#     movieId                                  title  \
# 0         1                       Toy Story (1995)
# 1         2                         Jumanji (1995)
# 2         3                Grumpier Old Men (1995)
# 3         4               Waiting to Exhale (1995)
# 4         5     Father of the Bride Part II (1995)
# 5         6                            Heat (1995)
# 6         7                         Sabrina (1995)
# 7         8                    Tom and Huck (1995)
# 8         9                    Sudden Death (1995)
# 9        10                       GoldenEye (1995)
# 10       11         American President, The (1995)
# 11       12     Dracula: Dead and Loving It (1995)
# 12       13                           Balto (1995)
# 13       14                           Nixon (1995)
# 14       15                Cutthroat Island (1995)
# 15       16                          Casino (1995)
# 16       17           Sense and Sensibility (1995)
# ...

# %%
#i want  to import the Tags
tags= pd.read_csv(r"C:\Data_Science\tag.csv\tag.csv")

tags
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
#I  wwant to import the rating dude
ratings=pd.read_csv(r"C:\Data_Science\rating.csv\rating.csv")
print(ratings)
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
row_0 = tags.iloc[0]
type(row_0)
print(row_0)
# Out:
# userId                        18
# movieId                     4141
# tag                  Mark Waters
# timestamp    2009-04-24 18:19:40
# Name: 0, dtype: object

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns[:]
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
#I want to get the informaion about the ratings
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
#we r use this one to get the highest value of specific column
ratings['rating'].max()
# Out:
# 5.0

# %%
#I want to know the min value of movieid
ratings['movieId'].min()
# Out:
# 1

# %%
#i Want to know inside the rating how much value is greater than 5
filter1= ratings['rating']>4
print(filter1)
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258     True
# 20000259     True
# 20000260    False
# 20000261     True
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool

# %%
#🔧 Data Cleaning: Handling Missing Data
#I want to know the total column inside the movie dataset
movies.shape[1]
# Out:
# 3

# %%
#I want to know the total number of rows and columns inside the tags
tags.shape
# Out:
# (465564, 4)

# %%
#Data Visullization
import seaborn as sns

# %%
ratings.hist(column='rating', figsize=(10,4))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
#Hey we can see 
ratings.boxplot(column='rating', figsize=(10,5))
# Out:
# <Axes: >

# %%
#By using this one we get the 10 row from the bottom 
ratings[-10:]
# Out:
#           userId  movieId  rating            timestamp
# 20000253  138493    60816     4.5  2009-12-03 18:32:43
# 20000254  138493    61160     4.0  2009-11-16 16:55:37
# 20000255  138493    65682     4.5  2009-10-17 21:52:53
# 20000256  138493    66762     4.5  2009-10-17 18:50:08
# 20000257  138493    68319     4.5  2009-12-07 18:15:20
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36

# %%
is_action= movies['genres'].str.contains('Action')
movies[is_action][5:15]
# Out:
#     movieId                                      title  \
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                            genres
# 22          Action|Crime|Thriller
# 41             Action|Crime|Drama
# 43       Action|Adventure|Fantasy
# 50          Action|Drama|Thriller
# 65         Action|Sci-Fi|Thriller
# 69  Action|Comedy|Horror|Thriller
# 70                         Action
# 75         Action|Sci-Fi|Thriller
# 77    Action|Crime|Drama|Thriller
# ...

# %%
movies[is_action].head(15)
# Out:
#     movieId                                      title  \
# 5         6                                Heat (1995)
# 8         9                        Sudden Death (1995)
# 9        10                           GoldenEye (1995)
# 14       15                    Cutthroat Island (1995)
# 19       20                         Money Train (1995)
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                                 genres
# 5                Action|Crime|Thriller
# ...

# %%
#Group by aggresgrate 
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      239125
# 1.0      680732
# 1.5      279252
# 2.0     1430997
# 2.5      883398
# 3.0     4291193
# 3.5     2200156
# 4.0     5561926
# 4.5     1534824
# 5.0     2898660

# %%
movie_count = ratings[['movieId','rating']].groupby('movieId').count()
movie_count.head()
# Out:
#          rating
# movieId
# 1         49695
# 2         22243
# 3         12735
# 4          2756
# 5         12161
