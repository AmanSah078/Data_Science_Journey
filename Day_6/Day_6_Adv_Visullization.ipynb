# %%
import pandas as pd

# %%
#I  wwant to import the rating dude
ratings=pd.read_csv(r"C:\Data_Science\rating.csv\rating.csv")
print(ratings)
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
import seaborn as sns

# %%
#Most ratings are concentrated between 3 and 5.

#The data is not evenly distributed because some ratings occur much more frequently than others.
sns.histplot(ratings['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
#it define the peak rating 
#The highest density is around rating 4.0.
sns.kdeplot(ratings['rating'], fill=True)
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %%
#To know about the outlier
#Median sns.violinplot(x=ratings['rating'])atings (around 0.5 and 1.0).
sns.boxplot(x=ratings['rating'])
# Out:
# <Axes: xlabel='rating'>

# %%
#Kis area mein data sabse zyada concentrated lag raha hai?
sns.violinplot(x=ratings['rating'])
# Out:
# <Axes: xlabel='rating'>
